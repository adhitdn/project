# %% [markdown]
# **ADHITYA DWI NUGRAHA**

# %% [markdown]
# # Importing Packages and Datas

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt
plt.style.use('fivethirtyeight')
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-49352766-b4e6-4f07-bebd-32d904b0ac2e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-49352766-b4e6-4f07-bebd-32d904b0ac2e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df_cust=pd.read_csv('Customer.csv')
df_ordit=pd.read_csv('Order_Items.csv')
df_orpay=pd.read_csv('Order_Payments.csv')
df_orrev=pd.read_csv('Order_Reviews.csv')
df_ord=pd.read_csv('Orders.csv')
df_procn=pd.read_csv('Product_Category_Name.csv')
df_prod=pd.read_csv('Products.csv')
df_sell=pd.read_csv('Sellers.csv')

# %% [markdown]
# # Adjusting Datas

# %%
df_cust_fix = df_cust.drop(columns='customer_unique_id',axis=1)
df_cust_fix.head()
# Out:
#                         customer_id  customer_zip_code_prefix  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7                     14409
# 1  18955e83d337fd6b2def6b18a428ac77                      9790
# 2  4e7b3e00288586ebd08712fdd0374a03                      1151
# 3  b2b6027bc5c5109e529d4dc6358b12c3                      8775
# 4  4f2d8ab171c80ec8364f7c12e35b23ad                     13056
#
#            customer_city customer_state
# 0                 franca             SP
# 1  sao bernardo do campo             SP
# 2              sao paulo             SP
# 3        mogi das cruzes             SP
# 4               campinas             SP

# %%
df_cust_fix.to_csv('customer_fix.csv',index=False)

# %%
df_prod_fix = df_prod.drop(df_prod.iloc[:,2:9], axis=1)
df_prod_fix.head()
# Out:
#                          product_id  product_category_name
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas

# %%
df_prod_fix.to_csv('product_fix.csv',index=False)

# %%
df_ordit_fix=df_ordit.drop(columns='order_item_id',axis=1)
df_ordit_fix.head()
# Out:
#                            order_id                        product_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214  4244733e06e7ecb4970a6e2683c13e61
# 1  00018f77f2f0320c557190d7a144bdd3  e5f2d52b802189ee658865ca93d83a8f
# 2  000229ec398224ef6ca0657da4fc703e  c777355d18b72b67abbeef9df44fd0fd
# 3  00024acbcdf0a6daa1e931b038114c75  7634da152a4610f1595efa32f14722fc
# 4  00042b26cf59d7ce69dfabb4e55b4fd9  ac6c3623068f30de03045865e4e10089
#
#                           seller_id  shipping_limit_date   price  \
# 0  48436dade18ac8b2bce089ec2a041202  2017-09-19 09:45:35   58.90
# 1  dd7ddc04e1b6c2c614352b383efe2d36  2017-05-03 11:05:13  239.90
# 2  5b51032eddd242adc84c38acab88f23d  2018-01-18 14:48:30  199.00
# 3  9d7a1d34a5052409006425275ba1c2b4  2018-08-15 10:10:18   12.99
# 4  df560393f3a51e74553ab94004ba5c87  2017-02-13 13:57:51  199.90
#
#    freight_value
# 0          13.29
# 1          19.93
# 2          17.87
# 3          12.79
# 4          18.14

# %%
df_ordit_fix.to_csv('ordit_fix.csv',index=False)

# %%
df_orpay_fix=df_orpay.drop(df_orpay.iloc[:,[1,3]],axis=1)
df_orpay_fix.head()
# Out:
#                            order_id payment_type  payment_value
# 0  b81ef226f3fe1789b1e8b2acac839d17  credit_card          99.33
# 1  a9810da82917af2d9aefd1278f1dcfa0  credit_card          24.39
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd  credit_card          65.71
# 3  ba78997921bbcdc1373bb41e913ab953  credit_card         107.78
# 4  42fdf880ba16b47b59251dd489d4441a  credit_card         128.45

# %%
df_orpay_fix.to_csv('orpay_fix.csv',index=False)

# %%
df_orrev_fix=df_orrev.drop(df_orrev.iloc[:,[3,4,6]],axis=1)
df_orrev_fix.head()
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_creation_date
# 0             4  2018-01-18 00:00:00
# 1             5  2018-03-10 00:00:00
# 2             5  2018-02-17 00:00:00
# 3             5  2017-04-21 00:00:00
# 4             5  2018-03-01 00:00:00

# %%
df_orrev_fix.to_csv('orrev_fix.csv',index=False)

# %%
df_ord_fix=df_ord.drop(df_ord.iloc[:,[2,4,6,7]],axis=1)
df_ord_fix.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_purchase_timestamp order_delivered_carrier_date
# 0      2017-10-02 10:56:33          2017-10-04 19:55:00
# 1      2018-07-24 20:41:37          2018-07-26 14:31:00
# 2      2018-08-08 08:38:49          2018-08-08 13:50:00
# 3      2017-11-18 19:28:06          2017-11-22 13:39:59
# 4      2018-02-13 21:18:39          2018-02-14 19:46:34

# %%
df_ord_fix.to_csv('order_fix.csv',index=False)

# %% [markdown]
# # Merging Datas

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-0d1fb681-5224-44e8-9777-46a9391f64d7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0d1fb681-5224-44e8-9777-46a9391f64d7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df_custmr=pd.read_csv('customer_fix.csv')
df_orditem=pd.read_csv('ordit_fix.csv')
df_orpaym=pd.read_csv('orpay_fix.csv')
df_orrevs=pd.read_csv('orrev_fix.csv')
df_ordrs=pd.read_csv('order_fix.csv')
df_product=pd.read_csv('product_fix.csv')
df_seller=pd.read_csv('Sellers.csv')

# %%
test1=df_custmr.merge(df_ordrs, how='right')
test1.head()
# Out:
#                         customer_id  customer_zip_code_prefix  \
# 0  9ef432eb6251297304e76186b10a928d                      3149
# 1  b0830fb4747a6c6d20dea0b8c802d7ef                     47813
# 2  41ce2a54c0b03bf3443c3d931a367089                     75265
# 3  f88197465ea7920adcdbec7375364d82                     59296
# 4  8ab97904e6daea8866dbdbc4fb7aad2c                      9195
#
#              customer_city customer_state                          order_id  \
# 0                sao paulo             SP  e481f51cbdc54678b7cc49136f2d6af7
# 1                barreiras             BA  53cdb2fc8bc7dce0b6741e2150273451
# 2               vianopolis             GO  47770eb9100c2d0c44946d9cf07ec65d
# 3  sao goncalo do amarante             RN  949d5b44dbf5de918fe9c16f97b45f8a
# 4              santo andre             SP  ad21c59c0840e6cb83a9ceb5573f8159
#
#   order_purchase_timestamp order_delivered_carrier_date
# 0      2017-10-02 10:56:33          2017-10-04 19:55:00
# ...

# %%
test2 = test1.merge(df_orpaym, how='right')
test2.head()
# Out:
#                         customer_id  customer_zip_code_prefix  customer_city  \
# 0  0a8556ac6be836b46b3e89920d59291c                     39801  teofilo otoni
# 1  f2c7fc58a9de810828715166c672f10a                      2422      sao paulo
# 2  25b14b69de0b6e184ae6fe2755e478f9                      2652      sao paulo
# 3  7a5d8efaaa1081f800628c30d2b0728f                     36060   juiz de fora
# 4  15fd6fb8f8312dbb4674e4518d6fa3b3                     18570        conchas
#
#   customer_state                          order_id order_purchase_timestamp  \
# 0             MG  b81ef226f3fe1789b1e8b2acac839d17      2018-04-25 22:01:49
# 1             SP  a9810da82917af2d9aefd1278f1dcfa0      2018-06-26 11:01:38
# 2             SP  25e8ea4e93396b6fa0d3dd708e76c1bd      2017-12-12 11:19:55
# 3             MG  ba78997921bbcdc1373bb41e913ab953      2017-12-06 12:04:06
# 4             SP  42fdf880ba16b47b59251dd489d4441a      2018-05-21 13:59:17
#
# ...

# %%
test3 = test2.merge(df_orditem, how='right')
test3.head()
# Out:
#                         customer_id  customer_zip_code_prefix  \
# 0  3ce436f183e68e07877b285a838db11a                   28013.0
# 1  f6dd3ec061db4e3987629fe6b26e5cce                   15775.0
# 2  6489ae5e4333f3693df5ad4372dab6d3                   35661.0
# 3  d4eb9395c8c0431ee92fce09860c5a06                   12952.0
# 4  58dbd0b2d70206bf40e62cd34e84d795                   13226.0
#
#            customer_city customer_state                          order_id  \
# 0  campos dos goytacazes             RJ  00010242fe8c5a6d1ba2dd792cb16214
# 1        santa fe do sul             SP  00018f77f2f0320c557190d7a144bdd3
# 2          para de minas             MG  000229ec398224ef6ca0657da4fc703e
# 3                atibaia             SP  00024acbcdf0a6daa1e931b038114c75
# 4        varzea paulista             SP  00042b26cf59d7ce69dfabb4e55b4fd9
#
#   order_purchase_timestamp order_delivered_carrier_date payment_type  \
# 0      2017-09-13 08:59:02          2017-09-19 18:34:16  credit_card
# ...

# %%
test4 = test3.merge(df_product, how='left')
test4.head()
# Out:
#                         customer_id  customer_zip_code_prefix  \
# 0  3ce436f183e68e07877b285a838db11a                   28013.0
# 1  f6dd3ec061db4e3987629fe6b26e5cce                   15775.0
# 2  6489ae5e4333f3693df5ad4372dab6d3                   35661.0
# 3  d4eb9395c8c0431ee92fce09860c5a06                   12952.0
# 4  58dbd0b2d70206bf40e62cd34e84d795                   13226.0
#
#            customer_city customer_state                          order_id  \
# 0  campos dos goytacazes             RJ  00010242fe8c5a6d1ba2dd792cb16214
# 1        santa fe do sul             SP  00018f77f2f0320c557190d7a144bdd3
# 2          para de minas             MG  000229ec398224ef6ca0657da4fc703e
# 3                atibaia             SP  00024acbcdf0a6daa1e931b038114c75
# 4        varzea paulista             SP  00042b26cf59d7ce69dfabb4e55b4fd9
#
#   order_purchase_timestamp order_delivered_carrier_date payment_type  \
# 0      2017-09-13 08:59:02          2017-09-19 18:34:16  credit_card
# ...

# %%
test5 = test4.merge(df_orrevs, how='left')
test5.head()
# Out:
#                         customer_id  customer_zip_code_prefix  \
# 0  3ce436f183e68e07877b285a838db11a                   28013.0
# 1  f6dd3ec061db4e3987629fe6b26e5cce                   15775.0
# 2  6489ae5e4333f3693df5ad4372dab6d3                   35661.0
# 3  d4eb9395c8c0431ee92fce09860c5a06                   12952.0
# 4  58dbd0b2d70206bf40e62cd34e84d795                   13226.0
#
#            customer_city customer_state                          order_id  \
# 0  campos dos goytacazes             RJ  00010242fe8c5a6d1ba2dd792cb16214
# 1        santa fe do sul             SP  00018f77f2f0320c557190d7a144bdd3
# 2          para de minas             MG  000229ec398224ef6ca0657da4fc703e
# 3                atibaia             SP  00024acbcdf0a6daa1e931b038114c75
# 4        varzea paulista             SP  00042b26cf59d7ce69dfabb4e55b4fd9
#
#   order_purchase_timestamp order_delivered_carrier_date payment_type  \
# 0      2017-09-13 08:59:02          2017-09-19 18:34:16  credit_card
# ...

# %%
test6 = test5.merge(df_seller, how='left')
test6.head()
# Out:
#                         customer_id  customer_zip_code_prefix  \
# 0  3ce436f183e68e07877b285a838db11a                   28013.0
# 1  f6dd3ec061db4e3987629fe6b26e5cce                   15775.0
# 2  6489ae5e4333f3693df5ad4372dab6d3                   35661.0
# 3  d4eb9395c8c0431ee92fce09860c5a06                   12952.0
# 4  58dbd0b2d70206bf40e62cd34e84d795                   13226.0
#
#            customer_city customer_state                          order_id  \
# 0  campos dos goytacazes             RJ  00010242fe8c5a6d1ba2dd792cb16214
# 1        santa fe do sul             SP  00018f77f2f0320c557190d7a144bdd3
# 2          para de minas             MG  000229ec398224ef6ca0657da4fc703e
# 3                atibaia             SP  00024acbcdf0a6daa1e931b038114c75
# 4        varzea paulista             SP  00042b26cf59d7ce69dfabb4e55b4fd9
#
#   order_purchase_timestamp order_delivered_carrier_date payment_type  \
# 0      2017-09-13 08:59:02          2017-09-19 18:34:16  credit_card
# ...

# %%
test6.to_csv('merge_data.csv',index=False)

# %% [markdown]
# # Data Cleaning

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-a11743b2-3497-4219-9962-e91e9ffee6a0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a11743b2-3497-4219-9962-e91e9ffee6a0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
main_data=pd.read_csv('merge_data.csv')
main_data.head()
# Out:
#                         customer_id  customer_zip_code_prefix  \
# 0  3ce436f183e68e07877b285a838db11a                   28013.0
# 1  f6dd3ec061db4e3987629fe6b26e5cce                   15775.0
# 2  6489ae5e4333f3693df5ad4372dab6d3                   35661.0
# 3  d4eb9395c8c0431ee92fce09860c5a06                   12952.0
# 4  58dbd0b2d70206bf40e62cd34e84d795                   13226.0
#
#            customer_city customer_state                          order_id  \
# 0  campos dos goytacazes             RJ  00010242fe8c5a6d1ba2dd792cb16214
# 1        santa fe do sul             SP  00018f77f2f0320c557190d7a144bdd3
# 2          para de minas             MG  000229ec398224ef6ca0657da4fc703e
# 3                atibaia             SP  00024acbcdf0a6daa1e931b038114c75
# 4        varzea paulista             SP  00042b26cf59d7ce69dfabb4e55b4fd9
#
#   order_purchase_timestamp order_delivered_carrier_date payment_type  \
# 0      2017-09-13 08:59:02          2017-09-19 18:34:16  credit_card
# ...

# %%
main_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 118310 entries, 0 to 118309
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   customer_id               118307 non-null  object
#  1   customer_zip_code_prefix  118307 non-null  float64
#  2   customer_city             118307 non-null  object
#  3   customer_state            118307 non-null  object
#  4   order_id                  118310 non-null  object
#  5   order_purchase_timestamp  118307 non-null  object
#  6   payment_type              118307 non-null  object
#  7   payment_value             118307 non-null  float64
#  8   product_id                118310 non-null  object
#  9   seller_id                 118310 non-null  object
#  10  shipping_limit_date       118310 non-null  object
#  11  price                     118310 non-null  float64
#  12  freight_value             118310 non-null  float64
# ...

# %%
main_data.isnull().sum()
# Out:
# customer_id                        3
# customer_zip_code_prefix           3
# customer_city                      3
# customer_state                     3
# order_id                           0
# order_purchase_timestamp           3
# order_delivered_carrier_date    1257
# payment_type                       3
# payment_value                      3
# product_id                         0
# seller_id                          0
# shipping_limit_date                0
# price                              0
# freight_value                      0
# product_category_name           1709
# review_id                        978
# review_score                     978
# review_creation_date             978
# seller_zip_code_prefix             0
# seller_city                        0
# seller_state                       0
# dtype: int64

# %% [markdown]
# There are some null in our dataset. I will erase it so our dataset will be cleaner.

# %%
data=main_data.dropna().reset_index(drop=True)
data.head()
# Out:
#                         customer_id  customer_zip_code_prefix  \
# 0  3ce436f183e68e07877b285a838db11a                   28013.0
# 1  f6dd3ec061db4e3987629fe6b26e5cce                   15775.0
# 2  6489ae5e4333f3693df5ad4372dab6d3                   35661.0
# 3  d4eb9395c8c0431ee92fce09860c5a06                   12952.0
# 4  58dbd0b2d70206bf40e62cd34e84d795                   13226.0
#
#            customer_city customer_state                          order_id  \
# 0  campos dos goytacazes             RJ  00010242fe8c5a6d1ba2dd792cb16214
# 1        santa fe do sul             SP  00018f77f2f0320c557190d7a144bdd3
# 2          para de minas             MG  000229ec398224ef6ca0657da4fc703e
# 3                atibaia             SP  00024acbcdf0a6daa1e931b038114c75
# 4        varzea paulista             SP  00042b26cf59d7ce69dfabb4e55b4fd9
#
#   order_purchase_timestamp order_delivered_carrier_date payment_type  \
# 0      2017-09-13 08:59:02          2017-09-19 18:34:16  credit_card
# ...

# %%
data.customer_zip_code_prefix = data['customer_zip_code_prefix'].astype('int64')

# %%
data.isnull().sum()
# Out:
# customer_id                     0
# customer_zip_code_prefix        0
# customer_city                   0
# customer_state                  0
# order_id                        0
# order_purchase_timestamp        0
# order_delivered_carrier_date    0
# payment_type                    0
# payment_value                   0
# product_id                      0
# seller_id                       0
# shipping_limit_date             0
# price                           0
# freight_value                   0
# product_category_name           0
# review_id                       0
# review_score                    0
# review_creation_date            0
# seller_zip_code_prefix          0
# seller_city                     0
# seller_state                    0
# dtype: int64

# %%
data1=data.drop(columns='shipping_limit_date',axis=1)
data1.head()
# Out:
#                         customer_id  customer_zip_code_prefix  \
# 0  3ce436f183e68e07877b285a838db11a                     28013
# 1  f6dd3ec061db4e3987629fe6b26e5cce                     15775
# 2  6489ae5e4333f3693df5ad4372dab6d3                     35661
# 3  d4eb9395c8c0431ee92fce09860c5a06                     12952
# 4  58dbd0b2d70206bf40e62cd34e84d795                     13226
#
#            customer_city customer_state                          order_id  \
# 0  campos dos goytacazes             RJ  00010242fe8c5a6d1ba2dd792cb16214
# 1        santa fe do sul             SP  00018f77f2f0320c557190d7a144bdd3
# 2          para de minas             MG  000229ec398224ef6ca0657da4fc703e
# 3                atibaia             SP  00024acbcdf0a6daa1e931b038114c75
# 4        varzea paulista             SP  00042b26cf59d7ce69dfabb4e55b4fd9
#
#   order_purchase_timestamp order_delivered_carrier_date payment_type  \
# 0      2017-09-13 08:59:02          2017-09-19 18:34:16  credit_card
# ...

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114437 entries, 0 to 114436
# Data columns (total 20 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   customer_id                   114437 non-null  object
#  1   customer_zip_code_prefix      114437 non-null  int64
#  2   customer_city                 114437 non-null  object
#  3   customer_state                114437 non-null  object
#  4   order_id                      114437 non-null  object
#  5   order_purchase_timestamp      114437 non-null  object
#  6   order_delivered_carrier_date  114437 non-null  object
#  7   payment_type                  114437 non-null  object
#  8   payment_value                 114437 non-null  float64
#  9   product_id                    114437 non-null  object
#  10  seller_id                     114437 non-null  object
#  11  price                         114437 non-null  float64
# ...

# %% [markdown]
# Our dataset already clean. I will rearrange the queue of the columns.

# %%
df = data1.iloc[:,[0,1,3,2,4,5,9,13,7,11,12,8,6,10,17,19,18,14,15,16]]
df.head()
# Out:
#                         customer_id  customer_zip_code_prefix customer_state  \
# 0  3ce436f183e68e07877b285a838db11a                     28013             RJ
# 1  f6dd3ec061db4e3987629fe6b26e5cce                     15775             SP
# 2  6489ae5e4333f3693df5ad4372dab6d3                     35661             MG
# 3  d4eb9395c8c0431ee92fce09860c5a06                     12952             SP
# 4  58dbd0b2d70206bf40e62cd34e84d795                     13226             SP
#
#            customer_city                          order_id  \
# 0  campos dos goytacazes  00010242fe8c5a6d1ba2dd792cb16214
# 1        santa fe do sul  00018f77f2f0320c557190d7a144bdd3
# 2          para de minas  000229ec398224ef6ca0657da4fc703e
# 3                atibaia  00024acbcdf0a6daa1e931b038114c75
# 4        varzea paulista  00042b26cf59d7ce69dfabb4e55b4fd9
#
#   order_purchase_timestamp                        product_id  \
# 0      2017-09-13 08:59:02  4244733e06e7ecb4970a6e2683c13e61
# ...

# %% [markdown]
# Check is customer_id column has duplicate rows or not. If yes, I will make it unique with no duplicate rows.

# %%
df.duplicated().sum()
# Out:
# 10791

# %% [markdown]
# There are 10,791 duplicates. I will remove it.

# %%
data_main = df.drop_duplicates(keep=False)
data_main.head()
# Out:
#                         customer_id  customer_zip_code_prefix customer_state  \
# 0  3ce436f183e68e07877b285a838db11a                     28013             RJ
# 1  f6dd3ec061db4e3987629fe6b26e5cce                     15775             SP
# 2  6489ae5e4333f3693df5ad4372dab6d3                     35661             MG
# 3  d4eb9395c8c0431ee92fce09860c5a06                     12952             SP
# 4  58dbd0b2d70206bf40e62cd34e84d795                     13226             SP
#
#            customer_city                          order_id  \
# 0  campos dos goytacazes  00010242fe8c5a6d1ba2dd792cb16214
# 1        santa fe do sul  00018f77f2f0320c557190d7a144bdd3
# 2          para de minas  000229ec398224ef6ca0657da4fc703e
# 3                atibaia  00024acbcdf0a6daa1e931b038114c75
# 4        varzea paulista  00042b26cf59d7ce69dfabb4e55b4fd9
#
#   order_purchase_timestamp                        product_id  \
# 0      2017-09-13 08:59:02  4244733e06e7ecb4970a6e2683c13e61
# ...

# %%
data_main.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Our data is no longer has duplicate. Also, our data already clean from null input.

# %%
data_main.to_csv('data_fix.csv',index=False)

# %% [markdown]
# # Exploratory Data Analysis + Feature Engineering

# %% [markdown]
# ## The majority of transactions by customers and sellers come from which regions?

# %%
data_main[['customer_state','customer_city','seller_state','seller_city']].describe()
# Out:
#        customer_state customer_city seller_state seller_city
# count           96247         96247        96247       96247
# unique             27          4022           22         577
# top                SP     sao paulo           SP   sao paulo
# freq            40336         14952        68320       23749

# %% [markdown]
# The majority of customers and sellers come from the state SP (Sao Paulo) and the city of Sao Paulo. A total of 40,336 customers are from Sao Paulo state with 14,952 of them being in Sao Paulo city. In addition, 68,320 sellers came from Sao Paulo state with 23,749 sellers coming from Sao Paulo city

# %%
data_main['customer_zip_code_prefix'].value_counts()
# Out:
# 22790    130
# 24230    118
# 24220    115
# 22775    108
# 29101    103
#         ...
# 64845      1
# 1208       1
# 59184      1
# 77660      1
# 59955      1
# Name: customer_zip_code_prefix, Length: 14709, dtype: int64

# %% [markdown]
# A total of 130 customers came from the area with the postal code 22790

# %%
data_main['seller_zip_code_prefix'].value_counts()
# Out:
# 14940    6973
# 5849     1998
# 9015     1751
# 13405    1425
# 15025    1241
#          ...
# 93510       1
# 1039        1
# 89022       1
# 5372        1
# 91910       1
# Name: seller_zip_code_prefix, Length: 2103, dtype: int64

# %% [markdown]
# A total of 6973 sellers came from the area with a postal code of 14940

# %%
data_main['customer_state'].value_counts().plot.pie(autopct='%1.1f%%')
plt.show()

# %% [markdown]
# As many as 41.9% of customers who make transactions come from Sao Paulo state

# %%
data_main['seller_state'].value_counts().plot.pie(autopct='%1.1f%%')
plt.show()

# %% [markdown]
# As many as 71% of sellers who make transactions come from Sao Paulo state

# %% [markdown]
# This condition is very reasonable and reasonable because Sao Paulo state is the largest and most populous state in Brazil. Sao Paulo is also the center of economy and trade there.

# %% [markdown]
# ## Which state generates the highest number of orders?

# %%
data_main.groupby('customer_state')['order_id'].count()
# Out:
# customer_state
# AC       78
# AL      412
# AM      148
# AP       64
# BA     3330
# CE     1314
# DF     2090
# ES     2010
# GO     1953
# MA      732
# MG    11262
# MS      688
# MT      898
# PA      944
# PB      520
# PE     1613
# PI      484
# PR     4813
# RJ    12480
# RN      483
# RO      244
# RR       39
# RS     5284
# SC     3419
# SE      332
# SP    40336
# TO      277
# Name: order_id, dtype: int64

# %%
top_orders_states = data_main.groupby("customer_state")["order_id"].count().reset_index().sort_values("order_id", ascending=False)
top_orders_states.rename(columns={"order_id":"count"}, inplace=True)
ax = sns.barplot(x="count", y="customer_state", data=top_orders_states[:10])
ax.set_title("TOP 10 states berdasarkan jumlah order")
plt.show()

# %% [markdown]
# Sao Paulo state accounted for the largest share in transactions with 40,336 transactions seen from the number of order_id. Seeing that there are also the most customers and sellers in Sao Paulo state, this is natural and shows that the economy is very active in Sao Paulo state.

# %% [markdown]
# ## Which city has the highest number of orders?

# %%
data_main['customer_city'].describe()
# Out:
# count         96247
# unique         4022
# top       sao paulo
# freq          14952
# Name: customer_city, dtype: object

# %%
top_orders_cities = data_main.groupby("customer_city")["order_id"].count().reset_index().sort_values("order_id", ascending=False)
top_orders_cities.rename(columns={"order_id":"count"}, inplace=True)
ax = sns.barplot(x="count", y="customer_city", data=top_orders_cities[:10])
ax.set_title("TOP 10 cities berdasarkan jumlah order")
# Out:
# Text(0.5, 1.0, 'TOP 10 cities berdasarkan jumlah order')

# %% [markdown]
# A total of more than 14,000 total orders occurred from Sao Paulo city. This number is the highest and is very far compared to other cities in Brazil

# %% [markdown]
# ## Which state has the biggest revenue generation?

# %%
top_orval_states = data_main.groupby("customer_state")["payment_value"].sum().reset_index().sort_values("payment_value", ascending=False)
top_orval_states["% of Total Payments"] = (top_orval_states["payment_value"] / top_orval_states["payment_value"].sum()) * 100
top_orval_states["Cum % of Total Payments"] = top_orval_states["% of Total Payments"].cumsum()

# %%
ax = sns.barplot(x="% of Total Payments", y="customer_state", data=top_orval_states[:10])
ax.set_title("TOP 10 states dengan revenue generation terbesar")
plt.show()

# %% [markdown]
# Sao Paulo state is still the highest for a state with revenue generation reaching more than 35% of total transaction payments

# %% [markdown]
# ## Which city has the biggest revenue generation?

# %%
top_orval_cities = data_main.groupby("customer_city")["payment_value"].sum().reset_index().sort_values("payment_value", ascending=False)
top_orval_cities["% of Total Payments"] = (top_orval_cities["payment_value"] / top_orval_cities["payment_value"].sum()) * 100
top_orval_cities["Cum % of Total Payments"] = top_orval_cities["% of Total Payments"].cumsum()

# %%
ax = sns.barplot(x="% of Total Payments", y="customer_city", data=top_orval_cities[:10])
ax.set_title("TOP 10 cities dengan revenue generation terbesar")
plt.show()

# %% [markdown]
# Just like the state, Sao Paulo city is the city with the largest revenue generation, which almost reaches 14% of total transaction payments

# %% [markdown]
# ## How is the distribution of time for customers to place orders?

# %%
data_main["order_purchase_timestamp"] = pd.to_datetime(data_main["order_purchase_timestamp"])
orderbyhour = data_main.groupby(data_main["order_purchase_timestamp"].dt.hour)["order_id"].count().reset_index().sort_values(by="order_purchase_timestamp", ascending=False)
orderbyhour.rename(columns={"order_id":"Total Orders", "order_purchase_timestamp": "Hour of Day"}, inplace=True)

# %%
plt.figure(figsize = (10,5))
ax = sns.barplot(x="Hour of Day", y="Total Orders", data=orderbyhour)
ax.set_title("Persebaran Order Berdasarkan Jam")
plt.show()

# %% [markdown]
# It can be seen that the number of orders placed by customers starts to increase from 6 o'clock to 11 o'clock, then reaches its peak at around 16 o'clock. From the range of 10-22 hours, the number of orders by customers is relatively high

# %%
orderbyday = data_main.groupby(data_main["order_purchase_timestamp"].dt.day_name())["order_id"].count().reset_index()
orderbyday.rename(columns={"order_id":"Total Orders", "order_purchase_timestamp": "Weekday Name"}, inplace=True)
orderbyday = orderbyday.sort_values(by="Total Orders", ascending=False)

# %%
plt.figure(figsize = (10,5))
ax = sns.barplot(x="Weekday Name", y="Total Orders", data=orderbyday)
ax.set_xlabel('Day')
ax.set_title("Persebaran Jumlah Order Berdasarkan Hari")
plt.show()

# %% [markdown]
# It can be seen that the number of orders on Monday was the highest at almost 16,000 orders. The number of orders on Saturday was the lowest with only less than 12,000. Surprisingly, the trend shows that the more towards the weekend, the number of orders decreases

# %%
orderbymonth = data_main.groupby(data_main["order_purchase_timestamp"].dt.month_name())["order_id"].count().reset_index()
orderbymonth.rename(columns={"order_id":"Total Orders", "order_purchase_timestamp": "Month Name"}, inplace=True)
orderbymonth = orderbymonth.sort_values(by="Total Orders", ascending=False)

# %%
plt.figure(figsize = (10,5))
ax = sns.barplot(x="Month Name", y="Total Orders", data=orderbymonth)
ax.set_xlabel('Month')
ax.set_title("Persebaran Jumlah Order Berdasarkan Bulan")
plt.show()

# %% [markdown]
# It can be seen that in August, the number of orders reached the highest point of more than 10,000 orders, followed by May, July, then March, etc. The lowest number of orders occurred in September which was only slightly larger than the 4,000 orders

# %% [markdown]
# ## How is the distribution of product categories purchased by customers?

# %%
top_category = data_main.groupby("product_category_name")["order_id"].count().reset_index().sort_values("order_id", ascending=False)
top_category.rename(columns={"order_id":"count"}, inplace=True)
ax = sns.barplot(x="count", y="product_category_name", data=top_category[:10])
ax.set_title("TOP 10 kategori produk berdasarkan jumlah order")
plt.show()

# %%
data_main['product_category_name'].describe()
# Out:
# count               96247
# unique                 73
# top       cama_mesa_banho
# freq                 9855
# Name: product_category_name, dtype: object

# %% [markdown]
# It can be seen that the cama_mesa_banho product category (bath table bed) is the best-selling category purchased by customers as many as 9,855 orders

# %% [markdown]
# ## How is the distribution of products purchased by customers?

# %%
top_prod = data_main.groupby("product_id")["order_id"].count().reset_index().sort_values("order_id", ascending=False)
top_prod.rename(columns={"order_id":"count"}, inplace=True)
ax = sns.barplot(x="count", y="product_id", data=top_prod[:10])
ax.set_title("TOP 10 produk berdasarkan jumlah order")
plt.show()

# %%
data_main['product_id'].describe()
# Out:
# count                                96247
# unique                               30219
# top       99a4788cb24856965c36a24e339b6058
# freq                                   471
# Name: product_id, dtype: object

# %% [markdown]
# It can be seen that the product with id 99a4788cb24856965c36a24e339b6058 is very in demand purchased by customers with the number of purchases reaching 471

# %% [markdown]
# ## How is the distribution of transaction prices by customers?

# %%
plt.figure(figsize=(10,5))
sns.histplot(x='price', data=data_main)
plt.title('Distribusi Harga')
plt.xlabel('Harga')
plt.show()

# %%
fin_data['price'].mean()
# Out:
# 126.49437457790894

# %% [markdown]
# It can be seen that the majority of transaction prices by customers are below BZR 1,000 with an average of BZR 126

# %% [markdown]
# ## How is the distribution of freight value of customer transactions?

# %%
plt.figure(figsize=(10,5))
sns.histplot(x='freight_value', data=data_main)
plt.title('Distribusi Freight Value')
plt.xlabel('Freight Value')
plt.show()

# %% [markdown]
# It can be seen that the majority of freight value of transactions is spread below 100

# %% [markdown]
# ## How is the distribution of customer payment options?

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='payment_type', data=data_main)
plt.title('Distribusi Tipe Pembayaran')
plt.xlabel('Tipe Pembayaran')
plt.ylabel('Jumlah Customer')
plt.show()

# %%
fin_data['payment_type'].value_counts().plot.pie(autopct='%1.1f%%')
plt.show()

# %%
data_main['payment_type'].describe()
# Out:
# count           96247
# unique              4
# top       credit_card
# freq            72003
# Name: payment_type, dtype: object

# %% [markdown]
# It can be seen that the type of payment using credit cards is very popular with customers with the number of uses reaching 72,003 times

# %% [markdown]
# ## How is the distribution of time for customers to make order reviews?

# %%
data_main["review_creation_date"] = pd.to_datetime(data_main["review_creation_date"])
reviewbyhour = data_main.groupby(data_main["review_creation_date"].dt.hour)["order_id"].count().reset_index().sort_values(by="review_creation_date", ascending=False)
reviewbyhour.rename(columns={"order_id":"Total Orders Reviewed", "review_creation_date": "Hour of Day"}, inplace=True)

# %%
plt.figure(figsize = (10,5))
ax = sns.barplot(x="Hour of Day", y="Total Orders Reviewed", data=reviewbyhour)
ax.set_title("Persebaran Order Review Berdasarkan Jam")
plt.show()

# %% [markdown]
# Based on the results of the dataset, it shows that all review orders are carried out at 00 o'clock. I don't know why only at 00 o'clock, it may be the rules or the system there

# %%
reviewbyday = data_main.groupby(data_main["review_creation_date"].dt.day_name())["order_id"].count().reset_index()
reviewbyday.rename(columns={"order_id":"Total Orders Reviewed", "review_creation_date": "Weekday Name"}, inplace=True)
reviewbyday = reviewbyday.sort_values(by="Total Orders Reviewed", ascending=False)

# %%
plt.figure(figsize = (10,5))
ax = sns.barplot(x="Weekday Name", y="Total Orders Reviewed", data=reviewbyday)
ax.set_xlabel('Day')
ax.set_title("Persebaran Order Review Berdasarkan Hari")
plt.show()

# %% [markdown]
# It is seen that the number of customers who provide product reviews is quite evenly distributed on Fridays, Saturdays, Tuesdays, Thursdays, and Wednesdays as the peak of more than 17,500 customers. The numbers were drastically reduced on Sunday and their lowest on Monday.

# %% [markdown]
# ## How is the distribution of product assessments by customers?

# %%
#top 10 berdasarkan review score
plt.figure(figsize=(12,12))
reviewscores = data_main.groupby("product_category_name")["review_score"].agg(["mean", "count"]).sort_values(by="mean",ascending=False)
bestrated = reviewscores[reviewsocres["count"]>=50][:10]
bestrated
# Out:
#                                         mean  count
# product_category_name
# livros_importados                   4.508772     57
# livros_interesse_geral              4.500000    510
# alimentos_bebidas                   4.469484    213
# livros_tecnicos                     4.404580    262
# construcao_ferramentas_ferramentas  4.373626     91
# portateis_casa_forno_e_cafe         4.363636     77
# malas_acessorios                    4.340587   1057
# alimentos                           4.323810    420
# dvds_blu_ray                        4.310345     58
# industria_comercio_e_negocios       4.285068    221

# %% [markdown]
# By qualifying a minimum of 50 assessments given by customers, it was found that the livros_importados category (imported books) became the highest rating holder with an average of 4.508772 out of 57 customer ratings. Livros_interesse_geral (General Interest Books) also received a high rating of 4.5 out of 510 customers

# %%
#bottom 10 berdasarkan review score 
worstrated = reviewscores[reviewscores["count"]>=50].sort_values(by='mean')[:10]
worstrated
# Out:
#                                       mean  count
# product_category_name
# fashion_roupa_masculina           3.601695    118
# moveis_escritorio                 3.687106   1109
# audio                             3.844828    348
# fashion_underwear_e_moda_praia    3.924370    119
# cama_mesa_banho                   3.934145   9855
# casa_conforto                     3.945368    421
# casa_construcao                   3.991247    457
# construcao_ferramentas_seguranca  4.032895    152
# telefonia                         4.033438   4157
# telefonia_fixa                    4.036458    192

# %% [markdown]
# By qualifying a minimum of 50 assessments given by customers, it was found that the fashion_roupa_masculina category (fashion men's clothing) became the lowest rating holder with an average of 3.601695 from the assessment of 118 customers. Moveis_escritorio (office furniture) is also fairly low with a rating of 3.687106 from 1109 customer ratings

# %% [markdown]
# ## How is the distribution of the review score by customers?

# %%
sns.countplot(data_main["review_score"])
data_main["review_score"].value_counts() / data_main["review_score"].count() * 100
# Out:
# 5.0    58.669881
# 4.0    19.489439
# 1.0    10.280840
# 3.0     8.373248
# 2.0     3.186593
# Name: review_score, dtype: float64

# %% [markdown]
# More than 58% of customers gave 5 ratings on the products purchased. More than 19% gave a value of 4. The rest gives a below 3 assessment of the purchased product

# %% [markdown]
# ## How is the distribution of time for sellers to submit orders to the expedition?

# %%
data_main["order_delivered_carrier_date"] = pd.to_datetime(data_main["order_delivered_carrier_date"])
shipbyhour = data_main.groupby(data_main["order_delivered_carrier_date"].dt.hour)["order_id"].count().reset_index().sort_values(by="order_delivered_carrier_date", ascending=False)
shipbyhour.rename(columns={"order_id":"Total Orders Shipped", "order_delivered_carrier_date": "Hour of Day"}, inplace=True)

# %%
plt.figure(figsize = (10,5))
ax = sns.barplot(x="Hour of Day", y="Total Orders Shipped", data=shipbyhour)
ax.set_title("Persebaran Ship Berdasarkan Jam")
plt.show()

# %% [markdown]
# It can be seen that the number of orders handed over to the expedition by the seller began to increase from 4 o'clock to 14 o'clock as the peak. The trend went up again in the 17-19 hour range, then decreased from the 19-00 hour range

# %%
shipbyday = data_main.groupby(data_main["order_delivered_carrier_date"].dt.day_name())["order_id"].count().reset_index()
shipbyday.rename(columns={"order_id":"Total Orders Shipped", "order_delivered_carrier_date": "Weekday Name"}, inplace=True)
shipbyday = shipbyday.sort_values(by="Total Orders Shipped", ascending=False)

# %%
plt.figure(figsize = (10,5))
ax = sns.barplot(x="Weekday Name", y="Total Orders Shipped", data=shipbyday)
ax.set_xlabel('Day')
ax.set_title("Persebaran Jumlah Ship Berdasarkan Hari")
plt.show()

# %% [markdown]
# It can be seen that the number of orders handed over to the expedition on Monday was the highest at more than 20,000 orders. The number of orders handed over to the expedition on Sunday was the lowest with a value close to 0. This result is very realistic because usually shops will close orders on weekends

# %%
shipbymonth = data_main.groupby(data_main["order_delivered_carrier_date"].dt.month_name())["order_id"].count().reset_index()
shipbymonth.rename(columns={"order_id":"Total Orders Shipped", "order_delivered_carrier_date": "Month Name"}, inplace=True)
shipbymonth = shipbymonth.sort_values(by="Total Orders Shipped", ascending=False)

# %%
plt.figure(figsize = (10,5))
ax = sns.barplot(x="Month Name", y="Total Orders Shipped", data=shipbymonth)
ax.set_xlabel('Month')
ax.set_title("Persebaran Jumlah Ship Berdasarkan Bulan")
plt.show()

# %% [markdown]
# It can be seen that in August, the number of orders handed over to the expedition reached the highest point of more than 10,000 orders, followed by May, July, then March, etc. The lowest number of orders occurred in September which was only slightly larger than the 4,000 orders

# %% [markdown]
# ## How long does it take on average for a seller to submit an order to an export after a customer places an order?

# %%
data_main.head()
# Out:
#                         customer_id  customer_zip_code_prefix customer_state  \
# 0  3ce436f183e68e07877b285a838db11a                     28013             RJ
# 1  f6dd3ec061db4e3987629fe6b26e5cce                     15775             SP
# 2  6489ae5e4333f3693df5ad4372dab6d3                     35661             MG
# 3  d4eb9395c8c0431ee92fce09860c5a06                     12952             SP
# 4  58dbd0b2d70206bf40e62cd34e84d795                     13226             SP
#
#            customer_city                          order_id  \
# 0  campos dos goytacazes  00010242fe8c5a6d1ba2dd792cb16214
# 1        santa fe do sul  00018f77f2f0320c557190d7a144bdd3
# 2          para de minas  000229ec398224ef6ca0657da4fc703e
# 3                atibaia  00024acbcdf0a6daa1e931b038114c75
# 4        varzea paulista  00042b26cf59d7ce69dfabb4e55b4fd9
#
#   order_purchase_timestamp                        product_id  \
# 0      2017-09-13 08:59:02  4244733e06e7ecb4970a6e2683c13e61
# ...

# %%
data_main['diff_car_pur'] = (pd.to_datetime(data_main.order_delivered_carrier_date) - pd.to_datetime(data_main.order_purchase_timestamp)).dt.days

print(str.format('Rata-rata waktu yang dibutuhkan seller untuk menyerahkan barang ke ekspedisi setelah customer melakukan pemesanan adalah: {:.0f} hari', data_main.diff_car_app.mean()))
# Out:
# Rata-rata waktu yang dibutuhkan seller untuk menyerahkan barang ke ekspedisi setelah customer melakukan pemesanan adalah: 3 hari

# %% [markdown]
# ## How long does it take on average for a customer to review an order that has arrived after placing an order?

# %%
data_main.head()
# Out:
#                         customer_id  customer_zip_code_prefix customer_state  \
# 0  3ce436f183e68e07877b285a838db11a                     28013             RJ
# 1  f6dd3ec061db4e3987629fe6b26e5cce                     15775             SP
# 2  6489ae5e4333f3693df5ad4372dab6d3                     35661             MG
# 3  d4eb9395c8c0431ee92fce09860c5a06                     12952             SP
# 4  58dbd0b2d70206bf40e62cd34e84d795                     13226             SP
#
#            customer_city                          order_id  \
# 0  campos dos goytacazes  00010242fe8c5a6d1ba2dd792cb16214
# 1        santa fe do sul  00018f77f2f0320c557190d7a144bdd3
# 2          para de minas  000229ec398224ef6ca0657da4fc703e
# 3                atibaia  00024acbcdf0a6daa1e931b038114c75
# 4        varzea paulista  00042b26cf59d7ce69dfabb4e55b4fd9
#
#   order_purchase_timestamp                        product_id  \
# 0      2017-09-13 08:59:02  4244733e06e7ecb4970a6e2683c13e61
# ...

# %%
data_main['diff_rev_pur'] = (pd.to_datetime(data_main.review_creation_date) - pd.to_datetime(data_main.order_purchase_timestamp)).dt.days

print(str.format('Rata-rata waktu yang dibutuhkan customer untuk review pesanan yang telah sampai setelah melakukan pemesanan adalah: {:.0f} hari', data_main.diff_rev_pur.mean()))
# Out:
# Rata-rata waktu yang dibutuhkan customer untuk review pesanan yang telah sampai setelah melakukan pemesanan adalah: 12 hari

# %% [markdown]
# ## Is there a correlation between the duration of order delivery and the review score by the customer?

# %%
print(data_main['diff_rev_pur'].corr(data_main['review_score']))
# Out:
# -0.30275920110209215

# %% [markdown]
# From the results obtained, the two variables have a negative correlation. A negative sign indicates that the correlation between the duration of delivery and the review score is the opposite. The more the duration of submissions increases, the review score will decrease, this is very logical. A correlation value far from -1 indicates that the correlation between the two features is not very significant

# %% [markdown]
# ## What is the correlation of all features used?

# %%
sns.heatmap(fin_data.corr(),annot=True,cmap='RdYlGn',linewidths=0.2) 
fig=plt.gcf()
fig.set_size_inches(10,8)
plt.show()

# %% [markdown]
# There are several points earned:
# 1. Price has a strong positive correlation with payment_value
# 2. No significant features affecting review_score
# 3. Review_score negatively correlated with diff_car_pur and diff_rev_pur. That is, when the diff_car_pur and diff_rev_pur values fall, the values of the review_score will go up. And vice versa

# %% [markdown]
# # Final Data

# %%
fin_data.head()
# Out:
#                         customer_id  customer_zip_code_prefix customer_state  \
# 0  3ce436f183e68e07877b285a838db11a                     28013             RJ
# 1  f6dd3ec061db4e3987629fe6b26e5cce                     15775             SP
# 2  6489ae5e4333f3693df5ad4372dab6d3                     35661             MG
# 3  d4eb9395c8c0431ee92fce09860c5a06                     12952             SP
# 4  58dbd0b2d70206bf40e62cd34e84d795                     13226             SP
#
#            customer_city                          order_id  \
# 0  campos dos goytacazes  00010242fe8c5a6d1ba2dd792cb16214
# 1        santa fe do sul  00018f77f2f0320c557190d7a144bdd3
# 2          para de minas  000229ec398224ef6ca0657da4fc703e
# 3                atibaia  00024acbcdf0a6daa1e931b038114c75
# 4        varzea paulista  00042b26cf59d7ce69dfabb4e55b4fd9
#
#   order_purchase_timestamp                        product_id  \
# 0      2017-09-13 08:59:02  4244733e06e7ecb4970a6e2683c13e61
# ...

# %%
fin_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 96247 entries, 0 to 114436
# Data columns (total 22 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   customer_id                   96247 non-null  object
#  1   customer_zip_code_prefix      96247 non-null  int64
#  2   customer_state                96247 non-null  object
#  3   customer_city                 96247 non-null  object
#  4   order_id                      96247 non-null  object
#  5   order_purchase_timestamp      96247 non-null  datetime64[ns]
#  6   product_id                    96247 non-null  object
#  7   product_category_name         96247 non-null  object
#  8   payment_type                  96247 non-null  object
#  9   price                         96247 non-null  float64
#  10  freight_value                 96247 non-null  float64
#  11  payment_value                 96247 non-null  float64
# ...

# %%
fin_data.describe()
# Out:
#        customer_zip_code_prefix         price  freight_value  payment_value  \
# count              96247.000000  96247.000000   96247.000000   96247.000000
# mean               35105.863913    126.494375      20.237526     150.390915
# std                29720.778257    190.615148      15.958824     201.453013
# min                 1003.000000      0.850000       0.000000       0.000000
# 25%                11410.000000     42.900000      13.260000      56.800000
# 50%                24445.000000     79.900000      16.430000      99.220000
# 75%                58433.500000    139.900000      21.350000     169.870000
# max                99980.000000   6735.000000     409.680000    6929.310000
#
#        seller_zip_code_prefix  review_score  diff_rev_pur  diff_car_pur
# count            96247.000000  96247.000000  96247.000000  96247.000000
# mean             24710.707108      4.130809     12.064875      2.689206
# ...

# %%
fin_data.describe(include=object)
# Out:
#                              customer_id customer_state customer_city  \
# count                              96247          96247         96247
# unique                             89171             27          4022
# top     9af2372a1e49340278e7c1ef8d749f34             SP     sao paulo
# freq                                  21          40336         14952
#
#                                 order_id                        product_id  \
# count                              96247                             96247
# unique                             89171                             30219
# top     fa65dad1b0e818e3ccc5cb0e39231352  99a4788cb24856965c36a24e339b6058
# freq                                  21                               471
#
#        product_category_name payment_type                         seller_id  \
# count                  96247        96247                             96247
# unique                    73            4                              2860
# ...

# %%
fin_data.isnull().sum()
# Out:
# customer_id                     0
# customer_zip_code_prefix        0
# customer_state                  0
# customer_city                   0
# order_id                        0
# order_purchase_timestamp        0
# product_id                      0
# product_category_name           0
# payment_type                    0
# price                           0
# freight_value                   0
# payment_value                   0
# order_delivered_carrier_date    0
# seller_id                       0
# seller_zip_code_prefix          0
# seller_state                    0
# seller_city                     0
# review_id                       0
# review_score                    0
# review_creation_date            0
# diff_rev_pur                    0
# diff_car_pur                    0
# dtype: int64

# %%
fin_data.duplicated().sum()
# Out:
# 0

# %%
fin_data.to_csv('Final_Data.csv',index=False)

# %% [markdown]
# # Conclusion

# %% [markdown]
# From the dataset used, I am trying to find insights in it. The insights I got were as follows:
#
# 1. Sao Paulo is a state as well as a city that is very important for the economy in Brazil. It can be seen that the number of transactions by customers and sellers there is very high when compared to other regions in Brazil. Given that Sao Paulo is the largest area with the most populous population in Brazil, this is quite natural. When viewed from the data, a comparison of the number of distant transactions can indicate economic inequality/inequality in Brazil. Therefore, as a business actor, you should be able to pay more attention to aspects of economic ability to adjust to target market conditions. In addition, when viewed from the comparison of revenue generation, as a government, it would be nice to be able to strive to support the facilities of underdeveloped areas to revive the economy there.
# 2. Customers in Brazil make transactions generally on weekdays in the range of 10 am to 10 pm. For the distribution of the month, the majority of customers place orders in the middle of the year. As a business actor, this can be used to do advertising in that hour range. This is of course more effective because the majority of customers are at least surfing looking for items to buy.
# 3. Customers in Brazil mostly buy products with the cama mesa banho category (bath, table, bed) with a comparison of the distribution that is not enough "jomplang". This seems to indicate that sleeping equipment is very popular and needed there. This data can be used for business actors to innovate related products. The product that sells well is 99a4788cb24856965c36a24e339b6058.
# 4. Customers in Brazil mostly buy products that cost less than BZR 1000 with the mean being at the value of BZR 126. This can be used as a consideration in terms of determining the price of the product to be marketed. The majority use credit card payment methods with the amount reaching almost 75% of the total transactions. This shows that the majority of customers there are more concerned with ease and flexibility in transactions.
# 5. Customers in Brazil mostly give a review score on the products they buy with a value above 4. This indicates that the products sold are quite good in terms of quality in meeting customer expectations. However, customers who give a rating of 1 are also not small, even more than assessments 2 and 3. In providing an assessment, it was found that the duration of delivery is enough to affect the customer. If the delivery duration is long, then customers tend to give an unsatisfactory review score, and vice versa.
#
# That's all the information that I can get, hopefully it can be a benefit. Thanks!
